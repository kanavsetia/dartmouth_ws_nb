# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide1.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide2.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide3.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide4.png" height="750" width="900" />

# %%
from IPython.display import YouTubeVideo
vid = YouTubeVideo("Xmq_FJd1oUQ",width=700, height=400, start=0, end=21, mute=1)
display(vid)

# %%
from IPython.display import YouTubeVideo
vid = YouTubeVideo("Xmq_FJd1oUQ",width=700, height=400, start=22, end=39, mute=1)
display(vid)

# %%
from IPython.display import YouTubeVideo
vid = YouTubeVideo("Xmq_FJd1oUQ",width=700, height=400, start=39, mute=1)
display(vid)

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide5.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide6.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide7.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide8.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide9.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide10.png" height="750" width="900" />

# %% [markdown]
# <img src="./dartmouth_winter_school_presentation/slide11.png" height="750" width="900" />
